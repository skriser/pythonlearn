# %%
from pyecharts import Bar
from pyecharts import Line

# %%
# 画简单的柱状图
bar = Bar("主标题", "这里是副标题")
# pyecharts 遵循所有图表都先定义数据在进行展示
bar.add("服装", ["衬衫", "羊毛衫", "雪纺衫","裤子", "高跟鞋", "袜子"], 
        [5, 20, 36, 10, 75, 90])

#方法一： 将图表渲染输出到html页面
# bar.render()    # 如果不穿参数，默认保存到当前文件夹下

# 方法二： 直接再jupyter中展示
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="f0bf2f70d73446ec907b5c9fd3fafc00" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_f0bf2f70d73446ec907b5c9fd3fafc00 = echarts.init(document.getElementById('f0bf2f70d73446ec907b5c9fd3fafc00'), 'light', {renderer: 'canvas'});
#
# var option_f0bf2f70d73446ec907b5c9fd3fafc00 = {
#     "title": [
#         {
#             "text": "\u4e3b\u6807\u9898",
#             "subtext": "\u8fd9\u91cc\u662f\u526f\u6807\u9898",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
# ...

# %%
# 2、根据柱状图绘制堆积图
attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [5, 20, 36, 10, 75, 90]
v2 = [10, 25, 8, 60, 20, 80]
# 添加标题
bar = Bar("柱状图数据堆叠示例")
# bar.add('商家A',attr,v1,is_stack=True)
# bar.add('商家B',attr,v2,is_stack=True)
# 柱状图添加标注点
bar.add("商家A", attr, v1, mark_point=["average"])
# 柱状图添加标注线
bar.add("商家B", attr, v2, mark_line=["min", "max"])
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="09378551c8844b88bd85361c88173a82" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_09378551c8844b88bd85361c88173a82 = echarts.init(document.getElementById('09378551c8844b88bd85361c88173a82'), 'light', {renderer: 'canvas'});
#
# var option_09378551c8844b88bd85361c88173a82 = {
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe\u6570\u636e\u5806\u53e0\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %%
attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [5, 20, 36, 10, 75, 90]
v2 = [10, 25, 8, 60, 20, 80]
# 添加标题
bar = Bar("柱状图数据堆叠示例")
# bar.add('商家A',attr,v1,is_stack=True)
# bar.add('商家B',attr,v2,is_stack=True)
# 柱状图添加标注点
bar.add("商家A", attr, v1, mark_point=["average"])
# 柱状图添加标注线
bar.add("商家B", attr, v2, mark_line=["min", "max"],is_convert=True) # 通过is_convert=True 进行x,y轴互换
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="bdc98358d979434fb6a5a158761ccc36" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_bdc98358d979434fb6a5a158761ccc36 = echarts.init(document.getElementById('bdc98358d979434fb6a5a158761ccc36'), 'light', {renderer: 'canvas'});
#
# var option_bdc98358d979434fb6a5a158761ccc36 = {
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe\u6570\u636e\u5806\u53e0\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %%
attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋",
"袜子"]
v1 = [5, 20, 36, 10, 10, 100]
v2 = [55, 60, 16, 20, 15, 80]
line = Line("折线图示例")
line.add("商家A", attr, v1, mark_point=["average"])
line.add("商家B", attr, v2, 
         mark_point_symbol='arrow',
         is_smooth=True,mark_line=["max", "average"])

line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="1019ec13258a4b1fa95de1f674aa348b" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_1019ec13258a4b1fa95de1f674aa348b = echarts.init(document.getElementById('1019ec13258a4b1fa95de1f674aa348b'), 'light', {renderer: 'canvas'});
#
# var option_1019ec13258a4b1fa95de1f674aa348b = {
#     "title": [
#         {
#             "text": "\u6298\u7ebf\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %%
attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [5, 20, 36, 10, 10, 100]
v2 = [55, 60, 16, 20, 15, 80]
line = Line("折线图示例")
line.add("商家A", attr, v1, mark_point=["average","max", "min"],
mark_point_symbol='diamond',
mark_point_textcolor='#40ff27')
line.add("商家B", attr, v2, mark_point=["average","max", "min"],mark_point_symbol='arrow',mark_point_symbolsize=40)
'''
mark_point : 标注点
mark_point_symbol : 标注点形状
mark_point_textcolor : 标注点字体颜色
mark_point_symbolsize: 标注点大小
'''
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="f7e11300f03a471c921d30def8c42249" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_f7e11300f03a471c921d30def8c42249 = echarts.init(document.getElementById('f7e11300f03a471c921d30def8c42249'), 'light', {renderer: 'canvas'});
#
# var option_f7e11300f03a471c921d30def8c42249 = {
#     "title": [
#         {
#             "text": "\u6298\u7ebf\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %%
# 折线图面积图实例
areaLine = Line('面积图示例')
areaLine.add('商家A',attr,v1,is_fill=True,area_opacity=0.4) # is_fill=True为折线图所包裹的区域填充颜色
areaLine.add('商家B',attr,v2,is_fill=True,area_color='#000',area_opacity=0.3)
areaLine
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="729db9645a8c4a188e031664d7e71529" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_729db9645a8c4a188e031664d7e71529 = echarts.init(document.getElementById('729db9645a8c4a188e031664d7e71529'), 'light', {renderer: 'canvas'});
#
# var option_729db9645a8c4a188e031664d7e71529 = {
#     "title": [
#         {
#             "text": "\u9762\u79ef\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %%
# 绘制饼状图
from pyecharts import Pie

attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [11, 12, 13, 10, 10, 10]
pie = Pie("饼图示例")
pie.add("", attr, v1, is_label_show=True)
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="3279e4fb2d504e86b40492f2d07408f2" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_3279e4fb2d504e86b40492f2d07408f2 = echarts.init(document.getElementById('3279e4fb2d504e86b40492f2d07408f2'), 'light', {renderer: 'canvas'});
#
# var option_3279e4fb2d504e86b40492f2d07408f2 = {
#     "title": [
#         {
#             "text": "\u997c\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %%
attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [11, 12, 13, 10, 10, 10]
pie = Pie("饼图-圆环图示例", title_pos='center')
pie.add("", attr, v1, radius=[40, 75], label_text_color=None,
        is_label_show=True, legend_orient='vertical',
        legend_pos='left')
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="ce1b23e5debd4204b13dfef626224574" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_ce1b23e5debd4204b13dfef626224574 = echarts.init(document.getElementById('ce1b23e5debd4204b13dfef626224574'), 'light', {renderer: 'canvas'});
#
# var option_ce1b23e5debd4204b13dfef626224574 = {
#     "title": [
#         {
#             "text": "\u997c\u56fe-\u5706\u73af\u56fe\u793a\u4f8b",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %%
from pyecharts import Map

value = [95.1, 23.2, 43.3, 66.4, 88.5]
attr= ["China", "Canada", "Brazil", "Russia", "United States"]
map1 = Map("世界地图示例", width=1200, height=600)
map1.add("dd", attr, value, maptype="world", is_visualmap=True,visual_text_color='#000')
map1.render()

# %%
from pyecharts import Scatter
v1 = [10, 20, 30, 40, 50, 60]
v2 = [10, 20, 30, 40, 50, 60]
scatter = Scatter("散点图示例")
scatter.add("A", v1, v2)
scatter.add("B", v1[::-1], v2)
scatter
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="b3b203249c6b4fcabde7392da67394e9" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_b3b203249c6b4fcabde7392da67394e9 = echarts.init(document.getElementById('b3b203249c6b4fcabde7392da67394e9'), 'light', {renderer: 'canvas'});
#
# var option_b3b203249c6b4fcabde7392da67394e9 = {
#     "title": [
#         {
#             "text": "\u6563\u70b9\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %%
from pyecharts import Scatter
v1 = [10, 20, 30, 40, 50, 60]
v2 = [10, 20, 30, 40, 50, 60]
scatter = Scatter("散点图示例")
scatter.add("A", v1, v2)
scatter.add("B", v1[::-1], v2, is_visualmap=True,
visual_type='size',
visual_range_size=[20, 80])
scatter
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="6818ce670a6346628d5a9502bf2119de" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_6818ce670a6346628d5a9502bf2119de = echarts.init(document.getElementById('6818ce670a6346628d5a9502bf2119de'), 'light', {renderer: 'canvas'});
#
# var option_6818ce670a6346628d5a9502bf2119de = {
#     "title": [
#         {
#             "text": "\u6563\u70b9\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %%
from pyecharts import Map
value = [155, 10, 66, 78,200,30]
attr = ["广东", "山东", "北京", "上海","安徽", "新疆"]
map = Map("全国地图示例", width=1200,
height=600)
map.add("", attr, value, maptype='china')
map
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="5dae4c39323845ac986db5233de2700f" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_5dae4c39323845ac986db5233de2700f = echarts.init(document.getElementById('5dae4c39323845ac986db5233de2700f'), 'light', {renderer: 'canvas'});
#
# var option_5dae4c39323845ac986db5233de2700f = {
#     "title": [
#         {
#             "text": "\u5168\u56fd\u5730\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
# ...

# %%
from pyecharts import Map
value = [20, 190, 253, 77, 65]
attr = ['汕头市', '汕尾市', '揭阳市', '阳江市', '肇庆市']
map = Map("广东地图示例", width=1200,
height=600)
map.add("", attr, value, maptype='广东',
is_visualmap=True,
visual_text_color='#000',is_label_show=True)
map
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'guangdong': '/nbextensions/echarts-china-provinces-js/guangdong'
#         }
#     });
# </script>
#     <div id="0b60b269b1c8489cbad64bc815702b09" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'guangdong'], function(echarts) {
#
# var myChart_0b60b269b1c8489cbad64bc815702b09 = echarts.init(document.getElementById('0b60b269b1c8489cbad64bc815702b09'), 'light', {renderer: 'canvas'});
#
# var option_0b60b269b1c8489cbad64bc815702b09 = {
#     "title": [
#         {
#             "text": "\u5e7f\u4e1c\u5730\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
# ...

# %%
from pyecharts import WordCloud
name = ['阿里云故障', '韩国对阵德国', '杨敬农获刑', '朱婷36分创纪录','德国队出局','暴雨毕业照走红', '孙兴慜假摔', '内马尔助攻席尔瓦', '世界杯',
        '结婚率逐年走低', '巴西2-0塞尔维亚','孟加拉外长访华', '凯塔加盟利物浦', '瑞典3-0墨西哥', '巴西设中国移民日', '直播手抓眼镜蛇','韩国2-0德国', '厄齐尔首发', 
        '墨西哥对阵瑞典','骑电动车坠渠溺亡']
value = [
428623, 367294, 356497, 351699, 350049, 348700, 348100, 347200, 345701,
341652, 330256, 329956, 306114, 260829, 229340, 166961, 158863, 148517, 145218, 144918]
wordcloud = WordCloud('绘制词云',width=1300, height=620)
wordcloud.add("", name, value, word_size_range=[20, 100])
wordcloud
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="e91bc332bb7c41b4b5da63b2444bf1f5" style="width:1300px;height:620px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_e91bc332bb7c41b4b5da63b2444bf1f5 = echarts.init(document.getElementById('e91bc332bb7c41b4b5da63b2444bf1f5'), 'light', {renderer: 'canvas'});
#
# var option_e91bc332bb7c41b4b5da63b2444bf1f5 = {
#     "title": [
#         {
#             "text": "\u7ed8\u5236\u8bcd\u4e91",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
# ...

# %%
# overlap 将多张图整合到一个画板上
from pyecharts import Bar,Line,Overlap

# %%
# 绘制柱状图
hero1 = ['鲁班','妲己','程咬金','后羿']
death_times = [1200,600,90,1000]

myBar = Bar('王者荣耀英雄死亡次数')
myBar.add('',hero1,death_times)
myBar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="87f0b327e35a4347bb17ae989993d0f7" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_87f0b327e35a4347bb17ae989993d0f7 = echarts.init(document.getElementById('87f0b327e35a4347bb17ae989993d0f7'), 'light', {renderer: 'canvas'});
#
# var option_87f0b327e35a4347bb17ae989993d0f7 = {
#     "title": [
#         {
#             "text": "\u738b\u8005\u8363\u8000\u82f1\u96c4\u6b7b\u4ea1\u6b21\u6570",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %%
# 绘制折线图
hero2 = ['鲁班','王昭君','孙悟空','典韦']
hurts = [2000,1200,3500,3000]

myLine = Line("六神装伤害输出")
myLine.add("",hero,hurts)
myLine
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="44d7ea4bc2de4686864782d34e686d82" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_44d7ea4bc2de4686864782d34e686d82 = echarts.init(document.getElementById('44d7ea4bc2de4686864782d34e686d82'), 'light', {renderer: 'canvas'});
#
# var option_44d7ea4bc2de4686864782d34e686d82 = {
#     "title": [
#         {
#             "text": "\u516d\u795e\u88c5\u4f24\u5bb3\u8f93\u51fa",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %%
overlap = Overlap()
overlap.add(myBar,is_add_axis=True)
overlap.add(myLine,is_add_axis=True)
overlap
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-ef40574816c7> in <module>()
#       1 overLap = Overlap()
# ----> 2 overLap.add(myBar,is_add_axis=True)
#       3 overLap.add(myLine,is_add_axis=True)
#       4 overLap
#
# TypeError: add() got an unexpected keyword argument 'is_add_axis'
